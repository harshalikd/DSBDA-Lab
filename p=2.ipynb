# %%
import pandas as pd

# %%
df=pd.read_csv("/home/nmietcomp/sample.csv")

# %%
df
# Out:
#   name   age   id   sub
# 0  NaN   NaN  NaN   NaN
# 1    a  12.0  1.0   bio
# 2    b  14.0  2.0   NaN
# 3    a  17.0  3.0  chem
# 4  NaN  20.0  4.0   NaN
# 5    d  22.0  5.0   NaN

# %%
df.isnull().sum()
# Out:
# name    2
# age     1
# id      1
# sub     4
# dtype: int64

# %%
df.dtypes
# Out:
# name     object
# age     float64
# id      float64
# sub      object
# dtype: object

# %%
df.size
# Out:
# 24

# %%
df.shape
# Out:
# (6, 4)

# %%
df.columns
# Out:
# Index(['name', 'age', 'id', 'sub'], dtype='object')

# %%
df.index
# Out:
# RangeIndex(start=0, stop=6, step=1)
