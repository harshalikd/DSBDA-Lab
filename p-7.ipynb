# %%
# !pip install nltk scikit-learn
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 40.4/40.4 kB 1.3 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 57.7/57.7 kB 1.1 MB/s eta 0:00:00 MB/s eta 0:00:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.6/1.6 MB 616.7 kB/s eta 0:00:00m eta 0:00:010:00:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 801.5/801.5 kB 371.7 kB/s eta 0:00:001m374.5 kB/s eta 0:00:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 108.3/108.3 kB 167.4 kB/s eta 0:00:00 kB/s eta 0:00:01:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 78.4/78.4 kB 209.2 kB/s eta 0:00:00 kB/s eta 0:00:01:01
# ...

# %%
import nltk
from nltk.tokenize import word_tokenize
from nltk.corpus import stopwords
from nltk.stem import PorterStemmer, WordNetLemmatizer
from nltk import pos_tag

from sklearn.feature_extraction.text import TfidfVectorizer

nltk.download('punkt')
nltk.download('stopwords')
nltk.download('averaged_perceptron_tagger')
nltk.download('wordnet')
# Out:
# [nltk_data] Downloading package punkt to /home/nmietcomp/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# [nltk_data] Downloading package stopwords to
# [nltk_data]     /home/nmietcomp/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     /home/nmietcomp/nltk_data...
# [nltk_data]   Unzipping taggers/averaged_perceptron_tagger.zip.
# [nltk_data] Downloading package wordnet to
# [nltk_data]     /home/nmietcomp/nltk_data...
# True

# %%
text = """Text analytics is the process of converting unstructured text into meaningful data.
It helps in extracting insights and patterns."""

# %%
import nltk

nltk.download('punkt')
nltk.download('punkt_tab')
# Out:
# [nltk_data] Downloading package punkt to /home/nmietcomp/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package punkt_tab to
# [nltk_data]     /home/nmietcomp/nltk_data...
# [nltk_data]   Package punkt_tab is already up-to-date!
# True

# %%
tokens = word_tokenize(text)
print("Tokens:\n", tokens)
# Out:
# Tokens:
#  ['Text', 'analytics', 'is', 'the', 'process', 'of', 'converting', 'unstructured', 'text', 'into', 'meaningful', 'data', '.', 'It', 'helps', 'in', 'extracting', 'insights', 'and', 'patterns', '.']

# %%
import nltk

nltk.download('averaged_perceptron_tagger_eng')
# Out:
# [nltk_data] Downloading package averaged_perceptron_tagger_eng to
# [nltk_data]     /home/nmietcomp/nltk_data...
# [nltk_data]   Package averaged_perceptron_tagger_eng is already up-to-
# [nltk_data]       date!
# True

# %%
pos_tags = nltk.pos_tag(tokens)
print("\nPOS Tags:\n", pos_tags)
# Out:
# POS Tags:
#  [('Text', 'NN'), ('analytics', 'NNS'), ('is', 'VBZ'), ('the', 'DT'), ('process', 'NN'), ('of', 'IN'), ('converting', 'VBG'), ('unstructured', 'JJ'), ('text', 'NN'), ('into', 'IN'), ('meaningful', 'JJ'), ('data', 'NNS'), ('.', '.'), ('It', 'PRP'), ('helps', 'VBZ'), ('in', 'IN'), ('extracting', 'VBG'), ('insights', 'NNS'), ('and', 'CC'), ('patterns', 'NNS'), ('.', '.')]

# %%
stop_words = set(stopwords.words('english'))
filtered_tokens = [word for word in tokens if word.lower() not in stop_words]

print("\nAfter Stopword Removal:\n", filtered_tokens)
# Out:
# After Stopword Removal:
#  ['Text', 'analytics', 'process', 'converting', 'unstructured', 'text', 'meaningful', 'data', '.', 'helps', 'extracting', 'insights', 'patterns', '.']

# %%
ps = PorterStemmer()
stemmed_words = [ps.stem(word) for word in filtered_tokens]

print("\nStemmed Words:\n", stemmed_words)
# Out:
# Stemmed Words:
#  ['text', 'analyt', 'process', 'convert', 'unstructur', 'text', 'meaning', 'data', '.', 'help', 'extract', 'insight', 'pattern', '.']

# %%
lemmatizer = WordNetLemmatizer()
lemmatized_words = [lemmatizer.lemmatize(word) for word in filtered_tokens]

print("\nLemmatized Words:\n", lemmatized_words)
# Out:
# Lemmatized Words:
#  ['Text', 'analytics', 'process', 'converting', 'unstructured', 'text', 'meaningful', 'data', '.', 'help', 'extracting', 'insight', 'pattern', '.']

# %%
from collections import Counter

tf = Counter(filtered_tokens)
print("\nTerm Frequency:\n", tf)
# Out:
# Term Frequency:
#  Counter({'.': 2, 'Text': 1, 'analytics': 1, 'process': 1, 'converting': 1, 'unstructured': 1, 'text': 1, 'meaningful': 1, 'data': 1, 'helps': 1, 'extracting': 1, 'insights': 1, 'patterns': 1})

# %%
documents = [text]

vectorizer = TfidfVectorizer()
tfidf_matrix = vectorizer.fit_transform(documents)

print("\nTF-IDF Matrix:\n", tfidf_matrix.toarray())
print("\nFeature Names:\n", vectorizer.get_feature_names_out())
# Out:
# TF-IDF Matrix:
#  [[0.21821789 0.21821789 0.21821789 0.21821789 0.21821789 0.21821789
#   0.21821789 0.21821789 0.21821789 0.21821789 0.21821789 0.21821789
#   0.21821789 0.21821789 0.21821789 0.43643578 0.21821789 0.21821789]]
#
# Feature Names:
#  ['analytics' 'and' 'converting' 'data' 'extracting' 'helps' 'in'
#  'insights' 'into' 'is' 'it' 'meaningful' 'of' 'patterns' 'process' 'text'
#  'the' 'unstructured']
